# %% [markdown]
# # Utility Functions

# %%
# %%writefile code/threshold.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology

import json
import sys
import pickle

fcompose = lambda *args: compose(*args[::-1])

mapdict = lambda **kwargs: map(lambda data: dict(dict((k, f(data)) for k, f in kwargs.items()), **data))

## Helper functions
@curry
def dfassign(df, **kwargs):
    return df.assign(**dict(((k, f(df)) for k, f in kwargs.items())))

## View the images
reshape = lambda arr: arr if len(arr.shape) == 2 else arr[...,0]
to_array = lambda image: reshape(numpy.asarray(image.convert("L")))

def plt_arrays(arrs):
    """Plot a set of (n, n) arrays as row column sub plots.
    """
    fig = matplotlib.pyplot.figure(figsize=(7, 7))
    N = int(numpy.ceil(numpy.sqrt(len(arrs))))
    for i, arr in enumerate(arrs):
        ax = fig.add_subplot(N, N, i + 1)
        out = ax.imshow(arr, cmap='Greys_r', interpolation='none')
        out.axes.get_xaxis().set_visible(False)
        out.axes.get_yaxis().set_visible(False)
    matplotlib.pyplot.tight_layout()
    matplotlib.pyplot.show()

## Extract the metadata
@curry
def crop_image(image, cutoff=960):
    """Crop the images into the "upper" and "lower" portions.

    Splits the image into the actual image of the microstructure and the embedded metadata.

    Args:
      image: a PIL image
      cutoff: the cutoff height for the upper image

    Returns:
      {'upper' : upper_image, 'lower': lower_image}
    """
    return dict(
               upper=image.crop(box=(0, 0, image.size[0], cutoff)),
               lower=image.crop(box=(0, cutoff, image.size[0], image.size[1]))
           )

def plt_array(arr):
    """Plot a single 2D array
    """
    ax = matplotlib.pyplot.imshow(arr, cmap='Greys_r', interpolation='none')
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    matplotlib.pyplot.tight_layout()
    matplotlib.pyplot.show()

# NBVAL_IGNORE_OUTPUT
repair_string = lambda string: float('10' if string == 'mum' else string.replace('pm', ''))

scale_pixels = fcompose(
    to_array,
    lambda data: skimage.measure.label(data, background=0),
    skimage.measure.regionprops,
    get(1),
    lambda data: data.bbox[3] - data.bbox[1],
)

extract_strings = fcompose(
    lambda image: pytesseract.image_to_string(image),
    lambda string: string.split(),
    get([1, 3, -1]),
    lambda data: dict(scale_microns=repair_string(data[0]),
                      date=data[1].replace('-', ''),
                      time=data[2])
)

extract_metadata = fcompose(
    PIL.Image.open,
    crop_image,
    get('lower'),
    lambda image: dict(scale_pixels=scale_pixels(image), **extract_strings(image))
)

## Rescale the images
extract_image = fcompose(
    PIL.Image.open,
    crop_image,
    get('upper')
)

def scale_image(image, rescale_factor):
    """Scale the image using PIL's thumbnail

    thumbnail is an inplace operation so copies are required.

    Args:
      image: a PIL image
      rescale_factor: how much to rescale the image by

    Returns:
      a new image
    """
    copy_image = image.copy()
    copy_image.thumbnail(numpy.array(copy_image.size) * rescale_factor, PIL.Image.ANTIALIAS)
    return copy_image

get_df = fcompose(
    glob.glob,
    sorted,
    map(
        lambda filename: dict(filename=filename,
                              **extract_metadata(filename))
    ),
    list,
    pandas.DataFrame,
    dfassign(pixel_size=lambda df: df['scale_microns'] / df['scale_pixels']),
    dfassign(rescale_factor=lambda df: df['pixel_size'] / max(df['pixel_size'])),
)

scaled_images = fcompose(
    get_df,
    lambda df: df.T.to_dict().values(),
    mapdict(image=lambda data: extract_image(data['filename'])),
    mapdict(scaled_image=lambda data: scale_image(data['image'], data['rescale_factor'])),
    list
)

## Threshold the images into the ferrite and cementite phase
threshold_image = fcompose(
    PIL.Image.open,
    crop_image,
    get('upper'),
    to_array,
    lambda data: data > skimage.filters.threshold_otsu(data)
)

def threshold(filename):

    result = dict(filename=filename,
                threshold_image=threshold_image(filename),
                **extract_metadata(filename))
    return result

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    result = threshold(filename)

    pickle.dump(result, open("{0}-threshold.data".format(filename_cleaned), 'wb'))
    
    print "{0}-threshold.data".format(filename_cleaned)
# Out:
# Overwriting code/threshold.py

# %%
# %%writefile code/min_size.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology

import sys
import json
import pickle

## Remove white specs
def f_min_size(scale_microns, scale_pixels, island_size=0.2):
    return (island_size * scale_pixels / scale_microns)**2

def min_size(data):
    data['min_size'] = f_min_size(data['scale_microns'], data['scale_pixels'])
    return data

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])

    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = min_size(data)
    pickle.dump(result, open("{0}-min_size.data".format(filename_cleaned), 'wb'))

    print "{0}-min_size.data".format(filename_cleaned)
# Out:
# Overwriting code/min_size.py

# %%
# %%writefile code/clean.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology

import json
import sys
import pickle

## Binary closing to reveal the Pearlite Phase
remove_small_holes = curry(skimage.morphology.remove_small_holes)

def clean(data):
    data['clean_image'] = ~remove_small_holes(~data['threshold_image'], data['min_size'])
    return data

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])
    
    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = clean(data)
    pickle.dump(result, open("{0}-clean.data".format(filename_cleaned), 'wb'))


    print "{0}-clean.data".format(filename_cleaned)
# Out:
# Overwriting code/clean.py

# %%
# %%writefile code/reveal.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology
import sys

import json
import pickle

fcompose = lambda *args: compose(*args[::-1])

## Binary closing to reveal the Pearlite Phase
closing = curry(flip(skimage.morphology.closing))
remove_small_holes = curry(skimage.morphology.remove_small_holes)

reveal_pearlite = fcompose(
    closing(skimage.morphology.square(5)),
    remove_small_holes(min_size=1000)
)

def reveal(data):
    data['pearlite_image'] = reveal_pearlite(data['clean_image'])
    return data

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])

    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = reveal(data)
    pickle.dump(result, open("{0}-reveal.data".format(filename_cleaned), 'wb'))

    print "{0}-reveal.data".format(filename_cleaned)
# Out:
# Overwriting code/reveal.py

# %%
# %%writefile code/ferrite.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology
import json
import sys
import pickle

## Volume function
frac1 = lambda image: float(image.sum()) / image.size
frac0 = lambda image: 1 - frac1(image)

def ferrite(data):
    data['ferrite_fraction'] = frac0(data['clean_image'])
    return data

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])
    
    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = ferrite(data)
    pickle.dump(result, open("{0}-ferrite.data".format(filename_cleaned), 'wb'))


    print "{0}-ferrite.data".format(filename_cleaned)
# Out:
# Overwriting code/ferrite.py

# %%
# %%writefile code/cemmentite.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology

import json
import sys
import pickle

## Volume function
frac1 = lambda image: float(image.sum()) / image.size

def cemmentite(data):
    data['cemmentite_fraction'] = frac1(data['clean_image'])
    return data

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])
    
    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = cemmentite(data)
    pickle.dump(result, open("{0}-cemmentite.data".format(filename_cleaned), 'wb'))


    print "{0}-cemmentite.data".format(filename_cleaned)
# Out:
# Overwriting code/cemmentite.py

# %%
# %%writefile code/save.py
import glob
import numpy
import matplotlib.pyplot
import scipy.ndimage
import pytesseract
import PIL.Image
from toolz.curried import map, pipe, compose, get, do, curry, count, pluck, juxt, flip
import pandas
import skimage
import skimage.measure
import skimage.filters
import skimage.morphology
import sys

import json
import pickle

def save(data):
    clean_name = data['filename'].split("/")[-1].split(".")[0]
    file_path = "{0}.json".format(clean_name)
    filtered_data = {}
    filtered_data['filename'] = clean_name
    filtered_data['pearlite_fraction'] = data['pearlite_fraction']
    filtered_data['ferrite_fraction'] = data['ferrite_fraction']
    filtered_data['cemmentite_fraction'] = data['cemmentite_fraction']
    with open(file_path, "w") as save_file:
        save_file.write(json.dumps(filtered_data, sort_keys=True, indent=4, separators=(',', ': ')))

if __name__ == '__main__':
    filename = sys.argv[1]
    filename_cleaned = filename.split("/")[-1].split(".")[0]
    filename_cleaned = "-".join(filename_cleaned.split("-")[0:-1])

    data = None
    with open(filename, "r") as intermediate:
        data = pickle.load(intermediate)

    result = save(data)
# Out:
# Overwriting code/save.py

# %% [markdown]
# # Study Spec Maestrowf

# %%
# %load sem-study.yaml
description:
    name: SEM-Images-Maestrowf
    description: The goal of this work is to analyze images of steel from SEM. The initial data set consists of 9 images.

env:
    variables:
        OUTPUT_PATH: ./sample_output/sem-image-stats
        SEM_IMG_STATS_URL: https://github.com/wd15/sem-image-stats
        PROJECT_PATH: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study
        CODE_PATH: $(PROJECT_PATH)/code
        DATA_PATH: $(PROJECT_PATH)/data
    labels:
        outfile: sem-image-stats.log
study:
    - name: run-threshold
      description: Do some thresholding.
      run:
          cmd: |
            python $(CODE_PATH)/threshold.py $(DATA_PATH)/$(DATA).tif
          depends: []
    - name: run-min_size
      description: Do some min_size.
      run:
          cmd: |
            python $(CODE_PATH)/min_size.py $(DATA)-threshold.data
          depends: [run-threshold]
    - name: run-clean
      description: Do some clean.
      run:
          cmd: |
            python $(CODE_PATH)/clean.py $(DATA)-min_size.data
          depends: [run-min_size]
    - name: run-reveal
      description: Do some reveal.
      run:
          cmd: |
            python $(CODE_PATH)/reveal.py $(DATA)-clean.data
          depends: [run-clean]
    - name: run-pearlite
      description: Do some ferrite.
      run:
          cmd: |
            python $(CODE_PATH)/pearlite.py $(DATA)-reveal.data
          depends: [run-reveal]
    - name: run-ferrite
      description: Do some ferrite.
      run:
          cmd: |
            python $(CODE_PATH)/ferrite.py $(DATA)-pearlite.data
          depends: [run-pearlite]
    - name: run-cemmentite
      description: Do some cemmentite.
      run:
          cmd: |
            python $(CODE_PATH)/cemmentite.py $(DATA)-ferrite.data
          depends: [run-ferrite]
    - name: run-save
      description: Do some save.
      run:
          cmd: |
            python $(CODE_PATH)/save.py $(DATA)-cemmentite.data
          depends: [run-cemmentite]

global.parameters:
    DATA:
        values  : ["1045_Steel_Nital-etch-1", "1045_Steel_Nital-etch-2", "1045_Steel_Nital-etch-3", "1045_Steel_Nital-etch-4", "1045_Steel_Nital-etch-5", "1045_Steel_Nital-etch-6", "1045_Steel_Nital-etch-7", "20150911_1045_Nital_etch-1", "20150911_1045_Nital_etch-2"]
        label   : "%%"
# Out:
#   File "<ipython-input-8-efe48f94da1d>", line 2
#     description:
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Running the study

# %%
! maestro -s -d 1 -y -c -t 2 sem-study.yaml
# Out:
# INFO:maestrowf.maestro:INFO Logging Level -- Enabled
# 2017-09-21 09:39:35,731 - maestrowf.maestro:setup_logging:131 - INFO - INFO Logging Level -- Enabled
# WARNING:maestrowf.maestro:WARNING Logging Level -- Enabled
# 2017-09-21 09:39:35,732 - maestrowf.maestro:setup_logging:132 - WARNING - WARNING Logging Level -- Enabled
# CRITICAL:maestrowf.maestro:CRITICAL Logging Level -- Enabled
# 2017-09-21 09:39:35,732 - maestrowf.maestro:setup_logging:133 - CRITICAL - CRITICAL Logging Level -- Enabled
# DEBUG:maestrowf.maestro:DEBUG Logging Level -- Enabled
# 2017-09-21 09:39:35,732 - maestrowf.maestro:setup_logging:134 - DEBUG - DEBUG Logging Level -- Enabled
# DEBUG:maestrowf.datastructures.core.study:Used Parameters -
# {'run-cemmentite': set(['DATA']), 'run-reveal': set(['DATA']), 'run-ferrite': set(['DATA']), 'run-pearlite': set(['DATA']), 'run-clean': set(['DATA']), 'run-threshold': set(['DATA']), 'run-min_size': set(['DATA']), 'run-save': set(['DATA'])}
# 2017-09-21 09:39:35,733 - maestrowf.datastructures.core.study:_setup_parameterized:368 - DEBUG - Used Parameters -
# {'run-cemmentite': set(['DATA']), 'run-reveal': set(['DATA']), 'run-ferrite': set(['DATA']), 'run-pearlite': set(['DATA']), 'run-clean': set(['DATA']), 'run-threshold': set(['DATA']), 'run-min_size': set(['DATA']), 'run-save': set(['DATA'])}
# DEBUG:maestrowf.datastructures.core.parameters:Adding parameter value to Combination with args: ['DATA', 'DATA', '1045_Steel_Nital-etch-1', '1045_Steel_Nital-etch-1']
# 2017-09-21 09:39:35,734 - maestrowf.datastructures.core.parameters:add:98 - DEBUG - Adding parameter value to Combination with args: ['DATA', 'DATA', '1045_Steel_Nital-etch-1', '1045_Steel_Nital-etch-1']
# DEBUG:maestrowf.datastructures.core.parameters:Parameter value: $(DATA) = 1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,734 - maestrowf.datastructures.core.parameters:add:100 - DEBUG - Parameter value: $(DATA) = 1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.core.parameters:Label value: $(DATA.label) = 1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,734 - maestrowf.datastructures.core.parameters:add:104 - DEBUG - Label value: $(DATA.label) = 1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.core.parameters:Name value: $(DATA.name) = DATA
# 2017-09-21 09:39:35,734 - maestrowf.datastructures.core.parameters:add:108 - DEBUG - Name value: $(DATA.name) = DATA
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,734 - maestrowf.datastructures.core.study:_setup_parameterized:375 - INFO - ==================================================
# INFO:maestrowf.datastructures.core.study:Expanding study 'SEM-Images-Stats' for combination '1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,735 - maestrowf.datastructures.core.study:_setup_parameterized:377 - INFO - Expanding study 'SEM-Images-Stats' for combination '1045_Steel_Nital-etch-1'
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,735 - maestrowf.datastructures.core.study:_setup_parameterized:378 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Source node found.
# 2017-09-21 09:39:35,735 - maestrowf.datastructures.core.study:_setup_parameterized:385 - DEBUG - Source node found.
# DEBUG:root:Adding _source...
# 2017-09-21 09:39:35,735 - root:add_node:60 - DEBUG - Adding _source...
# DEBUG:maestrowf.datastructures.dag:Node _source added. Value is of type <type 'NoneType'>.
# 2017-09-21 09:39:35,736 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node _source added. Value is of type <type 'NoneType'>.
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-threshold'.
# 2017-09-21 09:39:35,736 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-threshold'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,736 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-threshold' renamed to 'run-threshold_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,736 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-threshold' renamed to 'run-threshold_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-threshold_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,737 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-threshold_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-threshold_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,737 - root:add_node:60 - DEBUG - Adding run-threshold_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-threshold_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,737 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-threshold_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (_source, run-threshold_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,737 - root:add_edge:106 - INFO - Edge (_source, run-threshold_1045_Steel_Nital-etch-1) added.
# INFO:maestrowf.utils:Directory does not exist. Creating directories to /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,737 - maestrowf.utils:create_parentdir:80 - INFO - Directory does not exist. Creating directories to /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-1.tif
#
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-1.tif
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some thresholding.
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some thresholding.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-1.tif\n', 'depends': [], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-threshold_1045_Steel_Nital-etch-1', 'description': 'Do some thresholding.'}
# 2017-09-21 09:39:35,738 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-1.tif\n', 'depends': [], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-threshold_1045_Steel_Nital-etch-1', 'description': 'Do some thresholding.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-min_size'.
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-min_size'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-min_size' renamed to 'run-min_size_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-min_size' renamed to 'run-min_size_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-min_size_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,739 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-min_size_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-min_size_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,740 - root:add_node:60 - DEBUG - Adding run-min_size_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-min_size_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,740 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-min_size_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-threshold_1045_Steel_Nital-etch-1, run-min_size_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,740 - root:add_edge:106 - INFO - Edge (run-threshold_1045_Steel_Nital-etch-1, run-min_size_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/min_size.py 1045_Steel_Nital-etch-1-threshold.data
#
# 2017-09-21 09:39:35,740 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/min_size.py 1045_Steel_Nital-etch-1-threshold.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,740 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-min_size_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,740 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-min_size_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some min_size.
# 2017-09-21 09:39:35,740 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some min_size.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/min_size.py 1045_Steel_Nital-etch-1-threshold.data\n', 'depends': ['run-threshold_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-min_size_1045_Steel_Nital-etch-1', 'description': 'Do some min_size.'}
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/min_size.py 1045_Steel_Nital-etch-1-threshold.data\n', 'depends': ['run-threshold_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-min_size_1045_Steel_Nital-etch-1', 'description': 'Do some min_size.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-clean'.
# 2017-09-21 09:39:35,741 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-clean'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,742 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-clean' renamed to 'run-clean_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,742 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-clean' renamed to 'run-clean_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-clean_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,742 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-clean_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-clean_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,742 - root:add_node:60 - DEBUG - Adding run-clean_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-clean_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,742 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-clean_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-min_size_1045_Steel_Nital-etch-1, run-clean_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,743 - root:add_edge:106 - INFO - Edge (run-min_size_1045_Steel_Nital-etch-1, run-clean_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/clean.py 1045_Steel_Nital-etch-1-min_size.data
#
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/clean.py 1045_Steel_Nital-etch-1-min_size.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-min_size_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-min_size_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-clean_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-clean_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some clean.
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some clean.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/clean.py 1045_Steel_Nital-etch-1-min_size.data\n', 'depends': ['run-min_size_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-clean_1045_Steel_Nital-etch-1', 'description': 'Do some clean.'}
# 2017-09-21 09:39:35,743 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/clean.py 1045_Steel_Nital-etch-1-min_size.data\n', 'depends': ['run-min_size_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-clean_1045_Steel_Nital-etch-1', 'description': 'Do some clean.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-reveal'.
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-reveal'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-reveal' renamed to 'run-reveal_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-reveal' renamed to 'run-reveal_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-reveal_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,744 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-reveal_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-reveal_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,745 - root:add_node:60 - DEBUG - Adding run-reveal_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-reveal_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,745 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-reveal_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-clean_1045_Steel_Nital-etch-1, run-reveal_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,745 - root:add_edge:106 - INFO - Edge (run-clean_1045_Steel_Nital-etch-1, run-reveal_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/reveal.py 1045_Steel_Nital-etch-1-clean.data
#
# 2017-09-21 09:39:35,745 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/reveal.py 1045_Steel_Nital-etch-1-clean.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-clean_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,745 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-clean_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-reveal_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,745 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-reveal_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some reveal.
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some reveal.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/reveal.py 1045_Steel_Nital-etch-1-clean.data\n', 'depends': ['run-clean_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-reveal_1045_Steel_Nital-etch-1', 'description': 'Do some reveal.'}
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/reveal.py 1045_Steel_Nital-etch-1-clean.data\n', 'depends': ['run-clean_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-reveal_1045_Steel_Nital-etch-1', 'description': 'Do some reveal.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-pearlite'.
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-pearlite'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,746 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-pearlite' renamed to 'run-pearlite_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,747 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-pearlite' renamed to 'run-pearlite_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-pearlite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,747 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-pearlite_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-pearlite_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,747 - root:add_node:60 - DEBUG - Adding run-pearlite_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-pearlite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,747 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-pearlite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-reveal_1045_Steel_Nital-etch-1, run-pearlite_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,747 - root:add_edge:106 - INFO - Edge (run-reveal_1045_Steel_Nital-etch-1, run-pearlite_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/pearlite.py 1045_Steel_Nital-etch-1-reveal.data
#
# 2017-09-21 09:39:35,747 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/pearlite.py 1045_Steel_Nital-etch-1-reveal.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-reveal_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,747 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-reveal_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-pearlite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,748 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-pearlite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some ferrite.
# 2017-09-21 09:39:35,748 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some ferrite.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,753 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,753 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/pearlite.py 1045_Steel_Nital-etch-1-reveal.data\n', 'depends': ['run-reveal_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-pearlite_1045_Steel_Nital-etch-1', 'description': 'Do some ferrite.'}
# 2017-09-21 09:39:35,753 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/pearlite.py 1045_Steel_Nital-etch-1-reveal.data\n', 'depends': ['run-reveal_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-pearlite_1045_Steel_Nital-etch-1', 'description': 'Do some ferrite.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,754 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,755 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-ferrite'.
# 2017-09-21 09:39:35,755 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-ferrite'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,756 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-ferrite' renamed to 'run-ferrite_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,756 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-ferrite' renamed to 'run-ferrite_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-ferrite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,756 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-ferrite_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-ferrite_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,756 - root:add_node:60 - DEBUG - Adding run-ferrite_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-ferrite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,756 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-ferrite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-pearlite_1045_Steel_Nital-etch-1, run-ferrite_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,756 - root:add_edge:106 - INFO - Edge (run-pearlite_1045_Steel_Nital-etch-1, run-ferrite_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/ferrite.py 1045_Steel_Nital-etch-1-pearlite.data
#
# 2017-09-21 09:39:35,757 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/ferrite.py 1045_Steel_Nital-etch-1-pearlite.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-pearlite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,757 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-pearlite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-ferrite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,757 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-ferrite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some ferrite.
# 2017-09-21 09:39:35,757 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some ferrite.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,757 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/ferrite.py 1045_Steel_Nital-etch-1-pearlite.data\n', 'depends': ['run-pearlite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-ferrite_1045_Steel_Nital-etch-1', 'description': 'Do some ferrite.'}
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/ferrite.py 1045_Steel_Nital-etch-1-pearlite.data\n', 'depends': ['run-pearlite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-ferrite_1045_Steel_Nital-etch-1', 'description': 'Do some ferrite.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-cemmentite'.
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-cemmentite'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,758 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-cemmentite' renamed to 'run-cemmentite_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,759 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-cemmentite' renamed to 'run-cemmentite_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-cemmentite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,759 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-cemmentite_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-cemmentite_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,759 - root:add_node:60 - DEBUG - Adding run-cemmentite_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-cemmentite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,759 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-cemmentite_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-ferrite_1045_Steel_Nital-etch-1, run-cemmentite_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,759 - root:add_edge:106 - INFO - Edge (run-ferrite_1045_Steel_Nital-etch-1, run-cemmentite_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/cemmentite.py 1045_Steel_Nital-etch-1-ferrite.data
#
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/cemmentite.py 1045_Steel_Nital-etch-1-ferrite.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-ferrite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-ferrite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-cemmentite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-cemmentite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some cemmentite.
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some cemmentite.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,760 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/cemmentite.py 1045_Steel_Nital-etch-1-ferrite.data\n', 'depends': ['run-ferrite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-cemmentite_1045_Steel_Nital-etch-1', 'description': 'Do some cemmentite.'}
# 2017-09-21 09:39:35,761 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/cemmentite.py 1045_Steel_Nital-etch-1-ferrite.data\n', 'depends': ['run-ferrite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-cemmentite_1045_Steel_Nital-etch-1', 'description': 'Do some cemmentite.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,761 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,761 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-save'.
# 2017-09-21 09:39:35,761 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-save'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,761 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-save' renamed to 'run-save_1045_Steel_Nital-etch-1'
# 2017-09-21 09:39:35,762 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-save' renamed to 'run-save_1045_Steel_Nital-etch-1'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-save_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,762 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-save_1045_Steel_Nital-etch-1
# DEBUG:root:Adding run-save_1045_Steel_Nital-etch-1...
# 2017-09-21 09:39:35,762 - root:add_node:60 - DEBUG - Adding run-save_1045_Steel_Nital-etch-1...
# DEBUG:maestrowf.datastructures.dag:Node run-save_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,762 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-save_1045_Steel_Nital-etch-1 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (run-cemmentite_1045_Steel_Nital-etch-1, run-save_1045_Steel_Nital-etch-1) added.
# 2017-09-21 09:39:35,762 - root:add_edge:106 - INFO - Edge (run-cemmentite_1045_Steel_Nital-etch-1, run-save_1045_Steel_Nital-etch-1) added.
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/save.py 1045_Steel_Nital-etch-1-cemmentite.data
#
# 2017-09-21 09:39:35,763 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/save.py 1045_Steel_Nital-etch-1-cemmentite.data
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-cemmentite_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,763 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-cemmentite_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-save_1045_Steel_Nital-etch-1
# 2017-09-21 09:39:35,763 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-save_1045_Steel_Nital-etch-1
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some save.
# 2017-09-21 09:39:35,763 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some save.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,763 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,764 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# DEBUG:maestrowf.datastructures.core.study:step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/save.py 1045_Steel_Nital-etch-1-cemmentite.data\n', 'depends': ['run-cemmentite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-save_1045_Steel_Nital-etch-1', 'description': 'Do some save.'}
# 2017-09-21 09:39:35,764 - maestrowf.datastructures.core.study:_setup_parameterized:501 - DEBUG - step_exp = {'run': {'pre': '', 'cmd': 'python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/save.py 1045_Steel_Nital-etch-1-cemmentite.data\n', 'depends': ['run-cemmentite_1045_Steel_Nital-etch-1'], 'procs': '', 'post': '', 'nodes': '', 'restart': '', 'walltime': ''}, 'name': 'run-save_1045_Steel_Nital-etch-1', 'description': 'Do some save.'}
# DEBUG:maestrowf.datastructures.core.study:----------------------------------------
# 2017-09-21 09:39:35,764 - maestrowf.datastructures.core.study:_setup_parameterized:502 - DEBUG - ----------------------------------------
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,764 - maestrowf.datastructures.core.study:_setup_parameterized:507 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.parameters:Adding parameter value to Combination with args: ['DATA', 'DATA', '1045_Steel_Nital-etch-2', '1045_Steel_Nital-etch-2']
# 2017-09-21 09:39:35,764 - maestrowf.datastructures.core.parameters:add:98 - DEBUG - Adding parameter value to Combination with args: ['DATA', 'DATA', '1045_Steel_Nital-etch-2', '1045_Steel_Nital-etch-2']
# DEBUG:maestrowf.datastructures.core.parameters:Parameter value: $(DATA) = 1045_Steel_Nital-etch-2
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.parameters:add:100 - DEBUG - Parameter value: $(DATA) = 1045_Steel_Nital-etch-2
# DEBUG:maestrowf.datastructures.core.parameters:Label value: $(DATA.label) = 1045_Steel_Nital-etch-2
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.parameters:add:104 - DEBUG - Label value: $(DATA.label) = 1045_Steel_Nital-etch-2
# DEBUG:maestrowf.datastructures.core.parameters:Name value: $(DATA.name) = DATA
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.parameters:add:108 - DEBUG - Name value: $(DATA.name) = DATA
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.study:_setup_parameterized:375 - INFO - ==================================================
# INFO:maestrowf.datastructures.core.study:Expanding study 'SEM-Images-Stats' for combination '1045_Steel_Nital-etch-2'
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.study:_setup_parameterized:377 - INFO - Expanding study 'SEM-Images-Stats' for combination '1045_Steel_Nital-etch-2'
# INFO:maestrowf.datastructures.core.study:==================================================
# 2017-09-21 09:39:35,765 - maestrowf.datastructures.core.study:_setup_parameterized:378 - INFO - ==================================================
# DEBUG:maestrowf.datastructures.core.study:Source node found.
# 2017-09-21 09:39:35,766 - maestrowf.datastructures.core.study:_setup_parameterized:385 - DEBUG - Source node found.
# DEBUG:root:Adding _source...
# 2017-09-21 09:39:35,766 - root:add_node:60 - DEBUG - Adding _source...
# WARNING:maestrowf.datastructures.dag:Node _source already exists. Returning.
# 2017-09-21 09:39:35,766 - maestrowf.datastructures.dag:add_node:63 - WARNING - Node _source already exists. Returning.
# DEBUG:maestrowf.datastructures.core.study:Processing step 'run-threshold'.
# 2017-09-21 09:39:35,766 - maestrowf.datastructures.core.study:_setup_parameterized:389 - DEBUG - Processing step 'run-threshold'.
# DEBUG:maestrowf.datastructures.core.study:Used parameters set(['DATA'])
# 2017-09-21 09:39:35,766 - maestrowf.datastructures.core.study:_setup_parameterized:396 - DEBUG - Used parameters set(['DATA'])
# DEBUG:maestrowf.datastructures.core.study:Step has been modified. Step 'run-threshold' renamed to 'run-threshold_1045_Steel_Nital-etch-2'
# 2017-09-21 09:39:35,767 - maestrowf.datastructures.core.study:_setup_parameterized:403 - DEBUG - Step has been modified. Step 'run-threshold' renamed to 'run-threshold_1045_Steel_Nital-etch-2'
# DEBUG:maestrowf.datastructures.core.study:Resulting step name: run-threshold_1045_Steel_Nital-etch-2
# 2017-09-21 09:39:35,767 - maestrowf.datastructures.core.study:_setup_parameterized:405 - DEBUG - Resulting step name: run-threshold_1045_Steel_Nital-etch-2
# DEBUG:root:Adding run-threshold_1045_Steel_Nital-etch-2...
# 2017-09-21 09:39:35,767 - root:add_node:60 - DEBUG - Adding run-threshold_1045_Steel_Nital-etch-2...
# DEBUG:maestrowf.datastructures.dag:Node run-threshold_1045_Steel_Nital-etch-2 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# 2017-09-21 09:39:35,767 - maestrowf.datastructures.dag:add_node:66 - DEBUG - Node run-threshold_1045_Steel_Nital-etch-2 added. Value is of type <class 'maestrowf.datastructures.core.executiongraph._StepRecord'>.
# INFO:root:Edge (_source, run-threshold_1045_Steel_Nital-etch-2) added.
# 2017-09-21 09:39:35,767 - root:add_edge:106 - INFO - Edge (_source, run-threshold_1045_Steel_Nital-etch-2) added.
# INFO:maestrowf.utils:Directory does not exist. Creating directories to /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-2
# 2017-09-21 09:39:35,768 - maestrowf.utils:create_parentdir:80 - INFO - Directory does not exist. Creating directories to /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-2
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-2.tif
#
# 2017-09-21 09:39:35,768 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): python /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/code/threshold.py /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/corr-maestrowf/samples/sem-images-stats/study/data/1045_Steel_Nital-etch-2.tif
#
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-2
# 2017-09-21 09:39:35,768 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): run-threshold_1045_Steel_Nital-etch-2
# DEBUG:maestrowf.datastructures.environment.variable:$(OUTPUT_PATH): Do some thresholding.
# 2017-09-21 09:39:35,768 - maestrowf.datastructures.environment.variable:substitute:89 - DEBUG - $(OUTPUT_PATH): Do some thresholding.
# DEBUG:maestrowf.datastructures.core.study:---------------- Modified --------------
# 2017-09-21 09:39:35,769 - maestrowf.datastructures.core.study:_setup_parameterized:499 - DEBUG - ---------------- Modified --------------
# DEBUG:maestrowf.datastructures.core.study:Modified = True
# 2017-09-21 09:39:35,769 - maestrowf.datastructures.core.study:_setup_parameterized:500 - DEBUG - Modified = True
# ...
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-7/run-cemmentite_1045_Steel_Nital-etch-7.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,183 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-save_1045_Steel_Nital-etch-7
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-7/run-save_1045_Steel_Nital-etch-7.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,184 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-save_1045_Steel_Nital-etch-7
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/1045_Steel_Nital-etch-7/run-save_1045_Steel_Nital-etch-7.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,184 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-threshold_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-threshold_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,186 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-threshold_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-threshold_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,186 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-min_size_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-min_size_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,188 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-min_size_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-min_size_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,188 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-clean_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-clean_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,189 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-clean_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-clean_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,189 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-reveal_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-reveal_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,190 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-reveal_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-reveal_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,193 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-pearlite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-pearlite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,195 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-pearlite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-pearlite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,196 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-ferrite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-ferrite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,197 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-ferrite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-ferrite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,197 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-cemmentite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-cemmentite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,198 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-cemmentite_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-cemmentite_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,198 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-save_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-save_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,199 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-save_20150911_1045_Nital_etch-1
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-1/run-save_20150911_1045_Nital_etch-1.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,199 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-threshold_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-threshold_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,201 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-threshold_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-threshold_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,201 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-min_size_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-min_size_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,202 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-min_size_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-min_size_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,203 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-clean_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-clean_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,204 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-clean_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-clean_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,204 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-reveal_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-reveal_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,207 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-reveal_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-reveal_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,207 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-pearlite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-pearlite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,209 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-pearlite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-pearlite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,209 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-ferrite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-ferrite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,211 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-ferrite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-ferrite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,211 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-cemmentite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-cemmentite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,212 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-cemmentite_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-cemmentite_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# INFO:maestrowf.datastructures.core.executiongraph:Generating scripts...
# 2017-09-21 09:39:36,213 - maestrowf.datastructures.core.executiongraph:generate_scripts:226 - INFO - Generating scripts...
# INFO:maestrowf.datastructures.core.executiongraph:Step -- run-save_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-save_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# 2017-09-21 09:39:36,214 - maestrowf.datastructures.core.executiongraph:generate_scripts:233 - INFO - Step -- run-save_20150911_1045_Nital_etch-2
# Script: /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/20150911_1045_Nital_etch-2/run-save_20150911_1045_Nital_etch-2.sh
# Restart: None
# Scheduled?: False
# DEBUG:maestrowf.maestro:nohup conductor -t 2 -d 1 /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935 &> /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/SEM-Images-Stats.txt
# 2017-09-21 09:39:36,272 - maestrowf.maestro:main:196 - DEBUG - nohup conductor -t 2 -d 1 /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935 &> /Users/fyc/Desktop/Hackaton-09-11-2017/Demo/study/sample_output/sem-images-stats/SEM-Images-Stats_20170921-093935/SEM-Images-Stats.txt

# %%
! archive -f ~/Downloads/Maestrof-config.json sample_output/sem-images-stats/SEM-Images-Stats_20170915-094719/sem-study.yaml -d 1
